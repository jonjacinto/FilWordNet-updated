# %%
import glob
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Go to Shared GDrive directory containing data
base = "/content/drive/Shareddrives/DOST FilWordNet x WordSense/Thesis/Data Collection/RAW_COHFIE"
source_type = 'social_media'  #change
source = 'twitter'    #change
path = f'{base}/{source_type}/{source}/'
years = sorted(os.listdir(path))

document_count = 0
stop = False
stop_year = 2021
stop_month = 11

# directory iterate from year down to months 
for year in years:
    # print(f"PROCESSING: YEAR {year}")
    months = os.listdir(f'{path}/{year}/')
    months = [m for m in months if m.isnumeric()] # assumes folder names are numbers


    for month in months:
        print(f"PROCESSING: {year} {month}")

        data_path = f'{path}/{year}/{month}'
        # print(f"PROCESSING {data_path}")

        # get all the csv files in that directory (assuming they have the extension .json)
        json_files = glob.glob(f'{data_path}/*.json')

        for file in json_files:
            df = pd.read_json(file, orient='records')
            # print("DIMENSIONS:", df.shape[0])
            
            if not stop:
              document_count += df.shape[0]

            if f'/{year}/{month}' == f'{stop_month}':
              stop = True
# Out:
# PROCESSING: 2021 8
# PROCESSING: 2021 10
# PROCESSING: 2021 9
# PROCESSING: 2021 6
# PROCESSING: 2021 7
# PROCESSING: 2021 11

# %%
print(document_count)
# Out:
# 14576944

# %%
# Go to Shared GDrive directory containing data
base = "/content/drive/Shareddrives/DOST FilWordNet x WordSense/Thesis/Data Collection/RAW_COHFIE"
source_type = 'books'  #change
source = '100year'    #change
path = f'{base}/{source_type}/{source}/'
years = sorted(os.listdir(path))

document_count = 0
stop = False
stop_year = 2007
stop_month = 0

# set field
text_column_name = 'text'

# directory iterate from year down to months 
for year in years:
    print(f"PROCESSING: YEAR {year}")
    # months = os.listdir(f'{path}/{year}/')
    # months = [m for m in months if m.isnumeric()] # assumes folder names are numbers
    books = glob.glob(f'{path}{year}/*.cleaned')
    lst = []
    for book in books:
        lst.append(book)
    if not stop:
      document_count += len(books)
    if f'/{year}/{month}' == f'{stop_month}':
      stop = True
# Out:
# PROCESSING: YEAR 1901
# 1
# PROCESSING: YEAR 1902
# 2
# PROCESSING: YEAR 1905
# 2
# PROCESSING: YEAR 1907
# 3
# PROCESSING: YEAR 1908
# 7
# PROCESSING: YEAR 1909
# 3
# PROCESSING: YEAR 1910
# 3
# PROCESSING: YEAR 1911
# 3
# PROCESSING: YEAR 1912
# 2
# PROCESSING: YEAR 1913
# 3
# PROCESSING: YEAR 1914
# 2
# PROCESSING: YEAR 1918
# 1
# PROCESSING: YEAR 1920
# 2
# PROCESSING: YEAR 1921
# 2
# PROCESSING: YEAR 1922
# 2
# PROCESSING: YEAR 1923
# 1
# PROCESSING: YEAR 1925
# 1
# PROCESSING: YEAR 1933
# 2
# PROCESSING: YEAR 1935
# 1
# PROCESSING: YEAR 1936
# 2
# PROCESSING: YEAR 1937
# 3
# PROCESSING: YEAR 1938
# 1
# PROCESSING: YEAR 1941
# 1
# PROCESSING: YEAR 1942
# 1
# PROCESSING: YEAR 1945
# 1
# PROCESSING: YEAR 1946
# 2
# PROCESSING: YEAR 1949
# 1
# PROCESSING: YEAR 1956
# 1
# PROCESSING: YEAR 1959
# 1
# PROCESSING: YEAR 1974
# 1
# PROCESSING: YEAR 1976
# 1
# PROCESSING: YEAR 1980
# 1
# PROCESSING: YEAR 1986
# 1
# PROCESSING: YEAR 1989
# 1
# PROCESSING: YEAR 1999
# 2
# ...

# %%
# !ls '/content/drive/Shareddrives/DOST FilWordNet x WordSense/Thesis/Data Collection/RAW_COHFIE/books/100year/1910'
# Out:
#  0
#  1910_Masakim.txt.cleaned.noBlank.noHex.convHTML.tok.cleaned
#  DUWAG.txt.noBlank.noHex.convHTML.tok.cleaned
# 'mga pusong walang pag-ibig.txt.noBlank.noHex.convHTML.tok.cleaned'

# %%
print(document_count)
# Out:
# 100
