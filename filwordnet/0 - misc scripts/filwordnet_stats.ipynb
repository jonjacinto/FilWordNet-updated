# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_DIR = "/content/drive/Shareddrives/DOST FilWordNet x WordSense/Thesis/NLP Team/THS-ST3/final"

# %%
import pandas as pd
df = pd.read_csv(DATA_DIR+"/filwordnet.csv")
df.head()
# Out:
#      word  sense_id                                    sense_embedding  \
# 0  matino  matino_0  [ 3.92004242e-03  3.12551409e-02  4.41497937e-...
# 1  matino  matino_1  [ 1.42582236e-02 -7.32653495e-03  4.27205190e-...
# 2  matino  matino_2  [ 5.81043446e-03 -2.38136970e-03  4.27450798e-...
# 3  matino  matino_3  [-7.02383462e-03  1.44386766e-02  2.91953124e-...
# 4  maayos  maayos_0  [ 1.02245081e-02  2.21954919e-02  5.89414425e-...
#
#                                    example_sentences  \
# 0  ['halatang wala ka ng gagawing matino HAHAHA',...
# 1  ['May mga magulang na matino ang isip at kataw...
# 2  ['ng pelikula. Maganda at matino.', 'kasama sa...
# 3  ['akong sinabing matino.', 'Duda ako sa matino...
# 4  ['buti nalang nakasagot naman ng maayos.', 'sa...
#
#                                      contextual_info pos  synset_id
# 0                          {'twitter': {'2021': 10}}  FW         44
# 1  {'google_books': {'2018': 2}, 'twitter': {'202...  FW       2393
# ...

# %%
df.nunique()
# Out:
# word                 2598
# sense_id             7083
# sense_embedding      7083
# example_sentences    7083
# contextual_info      4492
# pos                    14
# synset_id            4301
# dtype: int64
