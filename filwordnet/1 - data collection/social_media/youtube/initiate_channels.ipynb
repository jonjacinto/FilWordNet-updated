# %%
# !pip install google-api-python-client

# %%
# Put your API key here
#API_KEY = input('Enter API key: ')
API_KEY = 'AIzaSyBO81_7IykA9UrZjw3uSQcAv6F9_yXneHU'

# %%
from googleapiclient.discovery import build
import json
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
script_link = "/content/drive/Shareddrives/DOST FilWordNet x WordSense/Thesis/Data Collection/Raw Data/Youtube/scripts"
save_link = "/content/drive/Shareddrives/DOST FilWordNet x WordSense/Thesis/Data Collection/Raw Data/Youtube/data"
files = os.listdir(script_link)
files
# Out:
# ['initiate_channels.ipynb',
#  'RogerRaker.csv',
#  'ranz_kyle.csv',
#  'channels.csv',
#  'Cong_TV.csv',
#  'video_comments.ipynb',
#  'add_channel.ipynb',
#  'update_channels.ipynb']

# %%
youtube = build('youtube','v3',developerKey=API_KEY)
max_videos = 50

# %% [markdown]
# #### 1.) Search the channel ID of the Channel & Get Uploads ID
# - search here: https://commentpicker.com/youtube-channel-id.php#youtube-channel-id
# - upload to channels.csv

# %% [markdown]
# revision: Iterate every channel title and ID to get Upload ID and corresponding videos.

# %%
channels = pd.read_csv(script_link+'/channels.csv')
channels
# Out:
#                     channel_title  ...                 upload_id
# 0                         cong_tv  ...  UU73zqrs0Th_a9dFUivEmv2A
# 1                    slater_young  ...                       NaN
# 2                        kryzzzie  ...                       NaN
# 3              alodia_gosiengfiao  ...                       NaN
# 4                      rei_germar  ...                       NaN
# ..                            ...  ...                       ...
# 139       i_can_see_your_voice_ph  ...                       NaN
# 140   the_boy_abunda_talk_channel  ...                       NaN
# 141             pinoy_big_brother  ...                       NaN
# 142                 unbox_diaries  ...                       NaN
# 143  the_voice_of_the_philippines  ...                       NaN
#
# [144 rows x 3 columns]

# %%
channels.iloc[:50]
# Out:
#              channel_title                channel_id                 upload_id
# 0                  cong_tv  UC73zqrs0Th_a9dFUivEmv2A  UU73zqrs0Th_a9dFUivEmv2A
# 1             slater_young  UCbwa4A6i0elG4WZGY7HRnKw                       NaN
# 2                 kryzzzie  UCyzvjriEiCVgLieY5Aesw1g                       NaN
# 3       alodia_gosiengfiao  UC66eoP3j29OuCIM0-K9RnsA                       NaN
# 4               rei_germar  UCMBfVjLDAebugEphxl9m_Eg                       NaN
# 5               ry_velasco  UCYCcIV0fYbg_tduACSWD_tQ                       NaN
# 6                 anna_cay  UCmre3CPYmzcMlVCaFUzkaag                       NaN
# 7               anne_clutz  UCDGdRHdLtV7VS_nWg9C2RVA                       NaN
# 8           anneclutzvlogs  UCiM0PLvHvQNWMLZd3ewo3Yg                       NaN
# 9            itsclaudineco  UCylA3YhDqkmvD_RNJWMJw9w                       NaN
# 10            abs_cbn_news  UCE2606prvXQc_noEqKxVJXA                       NaN
# ...

# %%
for index, row in channels.iterrows():
    print(row['channel_title'])
    # get the upload ID from the channel ID
    request = youtube.channels().list(
        part="contentDetails",
        id=row['channel_id'],
        maxResults = 1 # first channel only (most relative)
    )
    response = request.execute()
    # can sometimes be the same with channelID
    channels.loc[index, 'upload_id'] = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

channels.to_csv(script_link+"/channels.csv", index=False)
# Out:
# cong_tv
# slater_young
# kryzzzie
# alodia_gosiengfiao
# rei_germar
# ry_velasco
# anna_cay
# anne_clutz
# anneclutzvlogs
# itsclaudineco
# abs_cbn_news
# abs_cbn_entertainment
# alliana_dolina
# donnalyn_bartolome
# akosi_dogie
# carlo_ople
# oliver_austria
# kenny_manalad
# doc_willie_ong
# rendon_labador
# kiko_matos
# mika_salamanca
# presello
# alex_gonzaga_official
# h2wo
# shinejonzoief2p
# junnie_boy
# benedict_cua
# toni_gonzaga_studio
# tryke_gutierrez
# reccreate
# bermor
# rj_jacinto
# xtian_c
# fliptopbattles
# panlasang_pinoy
# bea_alonzo
# karl_jolice_tv
# dubstep
# front_seat_foodies
# nisky
# ninong_ry
# gma_public_affairs
# raffy_tulfo_in_action
# bonoy_pinty_gonzaga
# leti_sha
# wish_1075
# homesearch_philippines
# kiyo
# ben&ben
# vice_ganda
# jah_de_dios
# araw_na_itim_tagalog_animated_horror
# paolul
# mavs_phenomenal_basketball
# jonahrenz_jacob
# sb19_official
# karla_cayabyab
# mocha_uson_official
# leni_robredo
# jinkee_pacquiao
# team_pacquiao
# ...

# %%
channels
# Out:
#                     channel_title  ...                 upload_id
# 0                         cong_tv  ...  UU73zqrs0Th_a9dFUivEmv2A
# 1                    slater_young  ...  UUbwa4A6i0elG4WZGY7HRnKw
# 2                        kryzzzie  ...  UUyzvjriEiCVgLieY5Aesw1g
# 3              alodia_gosiengfiao  ...  UU66eoP3j29OuCIM0-K9RnsA
# 4                      rei_germar  ...  UUMBfVjLDAebugEphxl9m_Eg
# ..                            ...  ...                       ...
# 139       i_can_see_your_voice_ph  ...  UUQ2HM1jLRY8tpfib1zUjuNQ
# 140   the_boy_abunda_talk_channel  ...  UUKcX1SFIblkiYg8augik8_w
# 141             pinoy_big_brother  ...  UUsumo4lY8cd4v8Xt5zG3eSg
# 142                 unbox_diaries  ...  UU4hQDT1yzyH0KeSKAPJqeMg
# 143  the_voice_of_the_philippines  ...  UUuXGRLLomiSeJKHw7HnrtDg
#
# [144 rows x 3 columns]

# %% [markdown]
# #### 2.) Get Videos of Channel and save to CSV File

# %%
for index, row in channels.iterrows():
    '''
    Saves a CSV file containing video_id and video_title of all videos uploads playlist of a channel.
    Run if you want to get all videos from a channel.
    '''
    # variables
    video_id = []
    video_title = []
    video_description = []
    published_date = []

    # first run, get list of videos of uploads playlist
    request = youtube.playlistItems().list(
        part="snippet, contentDetails",
        maxResults=max_videos,
        playlistId=row['upload_id']
    )

    response_videoIDs = request.execute()

    # store relevant details from the response to list
    for video in response_videoIDs['items']:
        video_id.append(video['contentDetails']['videoId'])
        video_title.append(video['snippet']['title'])
        video_description.append(video['snippet']['description'])
        published_date.append(video['snippet']['publishedAt'])

    # # exhaust all videos of uploads playlist
    while 'nextPageToken' in response_videoIDs:
        request = youtube.playlistItems().list(
            part="snippet, contentDetails",
            maxResults=max_videos,
            playlistId=row['upload_id'],
            pageToken=response_videoIDs['nextPageToken']
        )

        response_videoIDs = request.execute()

        # store relevant details from the response to list
        for video in response_videoIDs['items']:
            video_id.append(video['contentDetails']['videoId'])
            video_title.append(video['snippet']['title'])
            video_description.append(video['snippet']['description'])
            published_date.append(video['snippet']['publishedAt'])

    # combine lists to DataFrame
    data = {'published_date': published_date,
            'video_id': video_id,
            'video_title': video_title,
            'description': video_description,
            'status': 'not_started',
            'nextPageToken': ''}

    # create and sort DataFrame
    df_results = pd.DataFrame(data=data)
    df_results.sort_values(by=['published_date'], ascending=True, ignore_index=True, inplace=True)

    # save to CSV
    df_results.to_csv(script_link + '/channels/' + row['channel_title']+".csv", index=False)
